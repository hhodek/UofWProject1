# %%
import json
import requests
import pandas as pd
from pprint import pprint

url = "https://open.canada.ca/data/api/action/package_show?id=cd88a55f-7d61-4714-968f-33d91ee6d112"

# %%
response = requests.get(url).json()

# %%
pprint(response)
# Out:
# {'help': 'https://open.canada.ca/data/api/3/action/help_show?name=package_show',
#  'result': {'association_type': [],
#             'audience': [],
#             'author': None,
#             'author_email': 'infostats@statcan.gc.ca',
#             'collection': 'primary',
#             'contributor': {},
#             'creator_user_id': '6b600515-c266-4584-a219-d084c980fd47',
#             'data_series_issue_identification': {'en': 'Table 22100111; '
#                                                        'Formerly CANSIM Table '
#                                                        '121-0002',
#                                                  'fr': 'Tableau 22100111; '
#                                                        'Anciennement Table '
#                                                        'CANSIM 121-0002'},
#             'data_series_name': {'en': 'Table', 'fr': 'Tableau'},
#             'date_published': '2017-11-30 08:30:00',
# ...

# %%
groups = response["result"]["groups"]
group
